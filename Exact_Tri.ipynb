# %%
import numpy as np

def Tri_Hamiltonian(length: int=3, gamma: float=1.) -> np.ndarray:
    
    size = int((length+1)*(length+2)/2)
    A = np.zeros((size, size))
    
    for i in [n+2 for n in range(length)]:
        base1 = int((i-2)*(i-1)/2)
        base2 = int((i-1)*i/2)
        for j in range(i-1):
            a1 = base1 + j
            a2_1 = base2 + j
            a2_2 = base2 + j + 1
            A[a1, a2_1] = -1
            A[a2_1, a1] = -1
            A[a1, a2_2] = -1
            A[a2_2, a1] = -1
            A[a2_1, a2_2] = -1
            A[a2_2, a2_1] = -1
    
    for i in range(size):
        A[i, i] = -A.sum(axis=1)[i]
    
    return gamma*A

# %%
import numpy as np

def Tri_MSD_weight(length: int=3) -> np.ndarray:
    
    weight = [0]
    for i in [n+2 for n in range(length)]:
        if i%2 == 0:
            sd = (i-1)**2 + i
            for j in reversed(range(int(i/2))):
                sd -= 2*(j+1)
                weight.append(sd)
            for j in range(int(i/2)):
                sd += 2*j
                weight.append(sd)
        else:
            sd = (i-1)**2 + i
            for j in reversed(range(int((i+1)/2))):
                sd -= 2*j+1
                weight.append(sd)
            for j in range(int((i-1)/2)):
                sd += 2*j+1
                weight.append(sd)
    
    return np.array(weight)

# %%
from matplotlib.colors import LinearSegmentedColormap

cdict = {'red':   ((0.00, 0.00, 0.00), 
                   (0.20, 0.95, 0.95),
                   (0.40, 0.95, 0.95),
                   (0.60, 0.95, 0.95),
                   (0.80, 0.95, 0.95),
                   (1.00, 0.00, 0.00)),

         'green': ((0.00, 0.00, 0.00), 
                   (0.20, 0.00, 0.00),
                   (0.40, 0.50, 0.50),
                   (0.60, 0.95, 0.95),
                   (0.80, 0.95, 0.95),
                   (1.00, 0.00, 0.00)),

         'blue':  ((0.00, 0.00, 0.00), 
                   (0.20, 0.00, 0.00),
                   (0.40, 0.30, 0.30),
                   (0.60, 0.50, 0.50),
                   (0.80, 0.95, 0.95),
                   (1.00, 0.95, 0.95))
          }

cmap = LinearSegmentedColormap('star', cdict)

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_distribution(G, pos, node_size=100, node_color="#1f78b4", mapper=None, cmap=None, vmin=None, vmax=None, ax=None):
    
    if ax is None:
        ax = plt.gca()
    
    nodes = nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color=node_color, cmap=cmap, vmin=vmin, vmax=vmax, ax=ax)
    edges = nx.draw_networkx_edges(G, pos, ax=ax)
    cb = plt.colorbar(mapper, ax=ax, extend='min')
    cb.ax.tick_params(labelsize=12)
    ax.axis('off')
    
    return nodes

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import expm

# %%
def qw(Hamiltonian: np.ndarray, t: float=1.) -> np.ndarray:
    
    H = Hamiltonian
    size = len(H)
    psi0 = np.zeros(size)
    psi0[0] = 1

    return abs(np.matmul(expm(-1j*np.pi*H*t), psi0))**2

# %%
order = 2
length = 3
steps = 300
dt = .01
t = np.linspace(dt, steps*dt, steps)
gamma = 1.

folder = 'exact/'
video_folder = 'videos/'
name = f'exact_tri_qw_ex_l{length}_{steps*dt:.1f}s_{steps:d}vly'

# %%
counts_list = np.zeros_like(t, dtype=object)
per10 = steps/10

for i in range(steps):
    counts_list[i] = qw(Tri_Hamiltonian(length, gamma), t[i])
    if i%per10==0:
        print(f'{int(i/per10)*10}%', end='\r')
print(f'{100}% complete!')
# Out:
# 100% complete!

# %%
msd_weight = Tri_MSD_weight(length)
msd_list = np.zeros_like(t, dtype=object)

for i in range(steps):
    msd_list[i] = (counts_list[i]*msd_weight).sum()

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(t[10:], msd_list[10:])
# plt.xscale("log")
# plt.yscale("log")
plt.show()

# %%
from matplotlib.colors import LogNorm
from matplotlib.cm import ScalarMappable

G = nx.from_numpy_array(abs(Tri_Hamiltonian(length, gamma)))
G.remove_edges_from(nx.selfloop_edges(G))
pos = nx.kamada_kawai_layout(G)

# vmin = 10**(1-order)
vmin = .5*10**(1-order)
vmax = 1.
mapper = ScalarMappable(norm=LogNorm(vmin=vmin, vmax=vmax), cmap=cmap)

# %%
choose = 49

dpi = 72
fig, ax = plt.subplots(figsize=(8, 6), dpi=dpi)

node_color = counts_list[choose]
time_template = 't = %.2fs'

nodes = draw_distribution(G, pos, ax=ax, node_color=mapper.to_rgba(node_color), mapper=mapper)
time_text = ax.text(-1, 1, time_template % ((choose+1)*dt), fontsize=18)

plt.show()

# %%
import csv

with open(f'{folder}{name}_msd_list.csv','w') as file :
    write = csv.writer(file)
    write.writerow(msd_list)

# %%
import pickle

with open(f'{folder}{name}_counts_list.pkl','wb') as file :
    pickle.dump(counts_list, file)

# %%
from matplotlib import animation

dpi = 300
playtime = 15
interval = int(playtime*1000/steps)
fps = int(steps/playtime)
fig, ax = plt.subplots(figsize=(8, 6), dpi=dpi)

node_color = counts_list[0]
time_template = 't = %.2fs'

nodes = draw_distribution(G, pos, ax=ax, node_color=mapper.to_rgba(node_color), mapper=mapper)
time_text = ax.text(-1, 1, time_template % 0., fontsize=18)

def animate(i):
    global nodes, time_text
    nodes.remove()
    time_text.remove()
    node_color = counts_list[i]
    nodes = nx.draw_networkx_nodes(G, pos, node_size=100, node_color=mapper.to_rgba(node_color))
    time_text = ax.text(-1, 1, time_template % ((i+1)*dt), fontsize=18)
    return 0

ani = animation.FuncAnimation(fig, animate, frames=steps, interval=interval)

def progress_callback(i, n):
    print(f'Saving frame {i} of {n}', end='\r')
    return 0

writer = animation.writers['ffmpeg'](fps=fps)
ani.save(f'{video_folder}{name}_animation.mp4', writer=writer, dpi=dpi, progress_callback=progress_callback)
del ani
plt.close(fig)
print(f'Saving frame {steps} of {steps} complete!')
# Out:
# Saving frame 300 of 300 complete!

# %%
def rw(Hamiltonian: np.ndarray, t: float=1.) -> np.ndarray:
    
    H = Hamiltonian
    size = len(H)
    psi0 = np.zeros(size)
    psi0[0] = 1

    return np.matmul(expm(-np.pi*H*t), psi0)

# %%
order = 4
length = 15
steps = 1500
dt = .01
t = np.linspace(dt, steps*dt, steps)
gamma = 1.

folder = 'exact/'
video_folder = 'videos/'
name = f'exact_tri_rw_ex_l{length}_{steps*dt:.1f}s_{steps:d}vly'

# %%
counts_list = np.zeros_like(t, dtype=object)
per10 = steps/10

for i in range(steps):
    counts_list[i] = rw(Tri_Hamiltonian(length, gamma), t[i])
    if i%per10==0:
        print(f'{int(i/per10)*10}%', end='\r')
print(f'{100}% complete!')
# Out:
# 100% complete!

# %%
msd_weight = Tri_MSD_weight(length)
msd_list = np.zeros_like(t, dtype=object)

for i in range(steps):
    msd_list[i] = (counts_list[i]*msd_weight).sum()

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(t[10:], msd_list[10:])
# plt.xscale("log")
# plt.yscale("log")
plt.show()

# %%
from matplotlib.colors import LogNorm
from matplotlib.cm import ScalarMappable

G = nx.from_numpy_array(abs(Tri_Hamiltonian(length, gamma)))
G.remove_edges_from(nx.selfloop_edges(G))
pos = nx.kamada_kawai_layout(G)

vmin = 10**(1-order)
vmax = 1.
mapper = ScalarMappable(norm=LogNorm(vmin=vmin, vmax=vmax), cmap=cmap)

# %%
choose = 800

dpi = 72
fig, ax = plt.subplots(figsize=(8, 6), dpi=dpi)

node_color = counts_list[choose]
time_template = 't = %.2fs'

nodes = draw_distribution(G, pos, ax=ax, node_color=mapper.to_rgba(node_color), mapper=mapper)
time_text = ax.text(-1, 1, time_template % ((choose+1)*dt), fontsize=18)

plt.show()

# %%
import csv

with open(f'{folder}{name}_msd_list.csv','w') as file :
    write = csv.writer(file)
    write.writerow(msd_list)

# %%
import pickle

with open(f'{folder}{name}_counts_list.pkl','wb') as file :
    pickle.dump(counts_list, file)

# %%
from matplotlib import animation

dpi = 300
playtime = 15
interval = int(playtime*1000/steps)
fps = int(steps/playtime)
fig, ax = plt.subplots(figsize=(8, 6), dpi=dpi)

node_color = counts_list[0]
time_template = 't = %.2fs'

nodes = draw_distribution(G, pos, ax=ax, node_color=mapper.to_rgba(node_color), mapper=mapper)
time_text = ax.text(-1, 1, time_template % 0., fontsize=18)

def animate(i):
    global nodes, time_text
    nodes.remove()
    time_text.remove()
    node_color = counts_list[i]
    nodes = nx.draw_networkx_nodes(G, pos, node_size=100, node_color=mapper.to_rgba(node_color))
    time_text = ax.text(-1, 1, time_template % ((i+1)*dt), fontsize=18)
    return 0

ani = animation.FuncAnimation(fig, animate, frames=steps, interval=interval)

def progress_callback(i, n):
    print(f'Saving frame {i} of {n}', end='\r')
    return 0

writer = animation.writers['ffmpeg'](fps=fps)
ani.save(f'videos/{name}_animation.mp4', writer=writer, dpi=dpi, progress_callback=progress_callback)
del ani
plt.close(fig)
print(f'Saving frame {steps} of {steps} complete!')
# Out:
# Saving frame 1500 of 1500 complete!
